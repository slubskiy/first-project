# %%
import pandas as pd #импортируем библиотеку pandas
data = pd.read_csv(r"D:\Y.Practicum\datasets\real_estate_data.csv", sep = '\t') #открываем датасет, указываем разделитель \t
print(data.head(10)) #выводим датасэт на экран для ознакомления
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
data["living_area"].hist()
data["living_area"].describe()
print(data.loc[data["living_area"] > 200])
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 660               3   49950000.0       483.9  2017-10-04T00:00:00      7
# 793              20  135000000.0       310.0  2018-05-22T00:00:00      4
# 866               5   25000000.0       363.0  2017-12-23T00:00:00     14
# 1085             16   75000000.0       323.0  2017-07-10T00:00:00      5
# 1494             10   65000000.0       364.0  2018-11-27T00:00:00      7
# 2580              6   30900000.0       338.6  2017-10-16T00:00:00      7
# 4237              1   50000000.0       517.0  2017-10-14T00:00:00      7
# 5358             20   65000000.0       590.0  2019-02-14T00:00:00     15
# 6221              8   34000000.0       470.3  2018-01-14T00:00:00      4
# 6621             20   99000000.0       488.0  2017-04-09T00:00:00      5
# 7857             11  150000000.0       230.0  2017-10-25T00:00:00      8
# 8018             20   84000000.0       507.0  2015-12-17T00:00:00      5
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.boxplot("living_area")
# Out:
# <AxesSubplot:>
